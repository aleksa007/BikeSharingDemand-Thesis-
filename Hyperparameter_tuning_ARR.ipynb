# %% [markdown]
# # Initialisation

# %%
import os

import re
import sys
import time
import math
import random
import pickle
import numpy as np
import string
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import scipy.stats as stat 
import statsmodels.api as sm
import seaborn as sns
import matplotlib.cm as cmap 
sns.set()

from pytz import timezone
from datetime import datetime
from sklearn import linear_model
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_regression 
from sklearn.cluster import KMeans
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from skimage.io import imread
from pathlib import Path
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf

from sklearn.linear_model import LinearRegression

from torch.utils.tensorboard import SummaryWriter

def SaveVariable(Variable, FileName):
    '''
    Saved any variable to the local drive
    '''
    DirName = Path(FileName).parent.absolute()
    os.makedirs(DirName, exist_ok = True)

    with open(FileName, 'wb') as io:
        pickle.dump(Variable, io)
    
def LoadVariable(FileName):
    '''
    Loads a variable from the local drive
    '''
    with open(FileName, "rb") as io:
        Res = pickle.load(io)
    return Res

def NpShift(arr, num, fill_value = np.nan):
    '''
    Shifts a numpy array by 'num' places
    '''
    result = np.empty_like(arr)
    if num > 0:
        result[:num] = fill_value
        result[num:] = arr[:-num]
    elif num < 0:
        result[num:] = fill_value
        result[:num] = arr[-num:]
    else:
        result[:] = arr
    return result

def NxDtoN2xTxD(X_Data, T):
    '''
    Transforms an NxD matrix to an (N-T)xTxD tensor
    '''
    if T != 0:
        tmp = X_Data
        X_Data = X_Data.reshape(-1, 1, X_Data.shape[1])
        for t in range(T):
            X_Data = np.concatenate((NpShift(tmp, t+1)[:, np.newaxis, :], X_Data), axis = 1)
        if T > 0:
            Y_Data = X_Data[T:, -1, :]
            X_Data = X_Data[T:, :-1, :]
        else:
            Y_Data = X_Data[:T, -1, :] #T is already negative
            X_Data = X_Data[:T, :-1, :] #T is already negative
        return X_Data, Y_Data
    
    else:
        if (False): print("NxDtoN2xTxD:", "T [{T}] can't be zero")
        return X_Data, None

def GetAndShowShapes(SupervisedType, YisX, X, Y, X_Train, Y_Train, X_Test, Y_Test, TrainDataset, train_loader, RowsToShow = 5):
    '''
    Retrieves the relevant shapes from the dataset and if (False): prints them
    '''
    SupervisedType = SupervisedType.lower()
    
    if X_Train is not None:
        if (False): print(f"X_Train[:{RowsToShow}]:\n", X_Train[:RowsToShow])
    else:
        if (False): print(f"X[:{RowsToShow}]:\n", X[:RowsToShow])        
    if (False): print()
    
    # number of classes
    if Y is not None:
        K = len(set(Y)) if SupervisedType == "classification" and len(set(Y)) != 2 else (Y.shape[1] if SupervisedType == "multivariateregression" else 1) #An output_size (K) > 1 can be either Multiclass or Multivariate-Regression, like Lat/Lon coordinates
    elif Y_Train is not None:
        K = len(set(Y_Train)) if SupervisedType == "classification" and len(set(Y_Train)) != 2 else (Y_Train.shape[1] if SupervisedType == "multivariateregression" else 1)
    elif YisX == True:    # When we Forecast and data is NxD, only later to be transformed to NxTxD,
        if X is not None: # Y is the latest/newest row of X, i.e. Y comes from X, there is no Y.
            K = X.shape[1]
        elif X_Train is not None:
            K = X_Train.shape[1]
        
    if len(X_Train.shape) == 2:
        N, D = X_Train.shape if X_Train is not None else X.shape
        H1, W1 = (0, 0)
    elif len(X_Train.shape) == 3:
        D = 0
        N, H1, W1 = X_Train.shape if X_Train is not None else X.shape
    elif len(X_Train.shape) == 4:
        N, H1, W1, D = X_Train.shape if X_Train is not None else X.shape
    
    if X is not None and Y is not None:
        if (False): print("X.shape      ", X.shape, "Y.shape      ", Y.shape)
    elif X is not None:
        if (False): print("X.shape      ", X.shape)
    if X_Train is not None and Y_Train is not None:
        if (False): print("X_Train.shape", X_Train.shape, "Y_Train.shape", Y_Train.shape)
    elif X_Train is not None:
        if (False): print("X_Train.shape", X_Train.shape)
    if X_Test is not None and Y_Test is not None:
        if (False): print("X_Test.shape ", X_Test.shape, "Y_Test.shape ", Y_Test.shape)
    elif X_Test is not None:
        if (False): print("X_Test.shape ", X_Test.shape)
    if X is not None:
        if (False): print(f"X: min = {X.min():.4f}, max = {X.max():.4f}")
    if X_Train is not None:
        if (False): print(f"X_Train: min = {X_Train.min():.4f}, max = {X_Train.max():.4f}")
    if (False): print("K         ", K)
    if (False): print("N:", N, "H1:", H1, "W1:", W1, "D:", D)

    if TrainDataset is not None:
        if (False): print(f"\nTrainDataset length: {len(TrainDataset)}")
        if (False): print(f"Data after transformation with batch size = {batch_size}:")
        if train_loader is not None:
            tmpX, tmpY = next(iter(train_loader))
            if (False): print("X.shape", tmpX.shape, "\tY.shape", tmpY.shape)

        #Sanity check:
        assert np.allclose(TrainDataset.__getitem__(0)[0][0], X_Train[0])
    
    return K, N, D, H1, W1

def PlotEachVarInX(X_Series):
    '''
    Plots a Pandas Series variable
    '''
    X_Series.plot()
    plt.ylabel(X_Series.name)
    plt.show()

def PlotEachLagVarInX(X_Series, lag = 1):
    '''
    Plots a lag_plot of a Pandas Series variable
    '''
    lag_plot(X_Series, lag = lag)
    plt.title(X_Series.name)
    plt.show()
    
def Var_LagVar_Cor(X_Series, lag = 1):
    '''
    Returns the correlation of a Pandas Series with its lagged version
    '''
    tmp = pd.concat([X_Series.shift(lag), X_Series], axis = 1)
    tmp.columns = [f't{int(math.copysign(lag, lag) * (-1))}', 't']
    return tmp.corr()

def PlotAutocorrelation(X_Series):
    '''
    Plots the autocorrelation_plot from Pandas on a Pandas Series
    '''
    pd.plotting.autocorrelation_plot(X_Series)
    plt.title(X_Series.name)
    plt.show()

def PlotAutocorrelationLineplot(X_Series, MaxLag = 31):
    '''
    Plots an autocorrelation line plots
    '''
    plot_acf(X_Series, lags = MaxLag)
    plt.title(X_Series.name)
    plt.xlabel("lag")
    plt.ylabel("Autocorrelation")
    plt.show()

# %% [markdown]
# # Data

# %%
#Setting the root directory / working directory
path_root = f"{os.getcwd()}"
print(path_root)
# Out:
# C:\Users\31636\OneDrive\Desktop\Thesis Data

# %%
def GetData(T):
    #############################
    ### Data Hyperparameters ####
    CustomNAString = None #If missing values are encoded with a string, which is the string?
    #############################


    #################
    ### One File ###
    XY = pd.read_csv(f"{path_root}/Data/sb_data.csv", header = 0, parse_dates=[['Date', 'Hour']])
    XY["Date_Hour"] = pd.to_datetime(XY["Date_Hour"], format="%d/%m/%Y %H")
    XY = XY.set_index(["Date_Hour"]) #XY = XY.reset_index()
    #################

    
    ####################
    ### Handling NAs ###
    NBeforeNADrop = len(XY)
    XY = XY.dropna()
    DroppedNARows = NBeforeNADrop - len(XY)
    if DroppedNARows > 0: print("Dropped NA rows count:", DroppedNARows)

    if CustomNAString is not None:
        NBeforeCustomNADrop = len(XY)
        XY = XY.replace(CustomNAString, np.nan, regex = False).dropna()
        DroppedCustomNARows = NBeforeCustomNADrop - len(XY)
        if DroppedCustomNARows > 0: print("Dropped custom NA rows count:", DroppedCustomNARows)
    ####################


    ################################
    ### Getting a Train/Test set ###
    ColumnsToKeepX = ["Rented Bike Count"] #Columns to keep
    X = XY[ColumnsToKeepX].values.astype(float) #Keeping those columns

    N = X.shape[0] #N number of observations

    TrainPerc = 0.9 #Training set is 90% of the data
    X_Train = X[:int(N * TrainPerc)] #Creating Training set
    X_Test = X[int(N * TrainPerc):]  #Creating Test set
    ################################


    ########################
    ### Scaling the Data ###
    scaler = StandardScaler(with_mean = True, with_std = True)
    X_Train = scaler.fit_transform(X_Train)
    X_Test = scaler.transform(X_Test)
    ########################


    ###################################
    ### Transform from NxD to NxTxD ###
    X_Train, Y_Train = NxDtoN2xTxD(X_Train, T) #Transforming from NxD to NxTxD
    X_Test, Y_Test = NxDtoN2xTxD(X_Test, T) #Transforming from NxD to NxTxD
    ###################################


    #Getting the K number of outputs, NTrain number of observations on training set, and D dimensions of X input
    K, NTrain, D, _, _ = GetAndShowShapes("Regression", True, X, None, X_Train, Y_Train, X_Test, Y_Test, None, None, RowsToShow = 0)
    
    return(X_Train, X_Test, Y_Train, Y_Test, K, N, NTrain, D)

# %% [markdown]
# # Hyperparameter Tuning

# %%
lags = list(set([T+1 for T in range(50, 350)])) #Tuning T/lag from 51 to 350
usebiases = list(set([True, False])) #Tunning bias over TRUE and FALSE


#######################
### HyperParameters ###
#######################
HP_lags = {'Lag': lags} #Creating a dictionary for the "lags"
HP_usebiases = {'Bia': usebiases} #Creating a dictionary for the usebiases


HParamsList = [HP_lags, HP_usebiases] #Concatenating all the hyperparameters together so we can iterate over them


##############
### Metrics ##
##############
#Regression
MT_Loss = {"mse": 'MSE'} #Creating a dictionary for the loss which is the Mean Squared Error
MT_RMSE = {"rmse": 'RMSE'} #creating a dictionary for the Root Mean Squared Error metric
MT_R2 = {"r2": 'R2'} #Creating a dictionary for the R2 model metric

MetricsList = [MT_Loss, MT_RMSE, MT_R2] #Concatenating all the metrics together

# %%
def RunGridSearch(run_dir, hparams, metric_dict, CurLogsDir, session_num):
    with SummaryWriter(run_dir) as SummWriter: #Creating a Tensorboard writer to save the hyperparameters and results there
        print(hparams)
        
        X_Train, X_Test, Y_Train, Y_Test, K, N, NTrain, D = GetData(hparams["Lag"]) #Reading the data and transforming them with T (lag) being iterated over the lags hyperparameter
        Y_Train = Y_Train.squeeze()
        Y_Test = Y_Test.squeeze()
#         print(X_Train.shape)
#         print(X_Test.shape)
#         print(Y_Train.shape)
#         print(Y_Test.shape)
#         raise Exception("DebugStop!")
        start_time = time.time() #Keeping the time

        #Instantiating the model and training it
        model = LinearRegression(fit_intercept = hparams["Bia"], normalize = False).fit(X_Train.squeeze(), Y_Train)
        Pred = model.predict(X_Test.squeeze()) #Making predictions
#         print(Pred.shape)
#         raise Exception("DebugStop!")
        Targets = Y_Test.copy()
        Predictions = Pred.copy()

        # if "scaler" in locals() or "scaler" in globals():
        #     Targets = scaler.inverse_transform(Targets)
        #     Predictions = scaler.inverse_transform(Predictions)

        #Calculating the error
        d1 = Targets - Predictions
        d2 = Targets - Targets.mean()
        r2 = 1 - d1.dot(d1) / d2.dot(d2)
        MSE = d1.dot(d1) / len(Targets) #Mean Squared Error
        RMSE = np.sqrt(MSE) #Root Mean Squared Error
        
        fig = plt.figure() #Plotting the Actual and Forecasted values
        plt.plot(Targets, label = f"Actual")
        plt.plot(Predictions, label = f"Forecasted")
        plt.legend()
        
        elapsed_time = time.time() - start_time
        print(f"session_num {session_num}. r2: {r2:.2f},  RMSE: {RMSE:.4f}") #Printing the metrics
        
        SummWriter.add_figure("Actual VS Forecast", fig, global_step = session_num, close = True) #Adding the plot to tensorboard
        
        TestLossVec.append(MSE) #Updating the metrics locally too, for reference
        R2CVec.append(r2)                
        RMSEVec.append(RMSE)
        
        SummWriter.add_hparams(hparam_dict = hparams, metric_dict = {"Loss": MSE, "R2": r2, "RMSE": RMSE}, hparam_domain_discrete = None, run_name = str(session_num)) #Writing the hyperparameters and metrics on tensorboard.

# %%
#initialising the variables
session_num = 0
TestLossVec = []
R2CVec = []
RMSEVec = []

#Creating the logs directory
logdir = "C:/logs"
os.makedirs(logdir, exist_ok = True)
CurTime = time.strftime("%Y-%m-%d_%H-%M-%S", time.localtime())
CurLogsDir = logdir + "/" + CurTime + "/"
os.mkdir(CurLogsDir)
os.mkdir(CurLogsDir + "hparam_tuning")

#Running Grid-search
for lag in lags:
    for usebias in usebiases:
        hparams = dict(zip([list(item.keys())[0] for item in HParamsList], [lag, usebias])) #Creating this run's hyperparameters dictionary
        metrics = {list(KV.keys())[0]: KV[list(KV.keys())[0]] for KV in MetricsList} #Creating the metrics dictionary

        #Creating tensorboard directories
        os.mkdir(CurLogsDir + "run-" + str(session_num))
        os.mkdir(CurLogsDir + "run-" + str(session_num) + "/train")
        os.mkdir(CurLogsDir + "run-" + str(session_num) + "/train/plugins")
        os.mkdir(CurLogsDir + "run-" + str(session_num) + "/train/plugins/profile")
        os.mkdir(CurLogsDir + "run-" + str(session_num) + "/validation")

        run_name = "run-%d" % session_num
        print('--- Starting trial: %s' % run_name)
        
        RunGridSearch(CurLogsDir + run_name, hparams, metrics, CurLogsDir, session_num)
        session_num += 1
print("ALL COMBINATIONS ARE NOW TRAINED!")
# Out:
# --- Starting trial: run-0
# {'Lag': 51, 'Bia': False}
# session_num 0. r2: 0.86,  RMSE: 0.2746
# --- Starting trial: run-1
# {'Lag': 51, 'Bia': True}
# session_num 1. r2: 0.86,  RMSE: 0.2746
# --- Starting trial: run-2
# {'Lag': 52, 'Bia': False}
# session_num 2. r2: 0.86,  RMSE: 0.2747
# --- Starting trial: run-3
# {'Lag': 52, 'Bia': True}
# session_num 3. r2: 0.86,  RMSE: 0.2747
# --- Starting trial: run-4
# {'Lag': 53, 'Bia': False}
# session_num 4. r2: 0.86,  RMSE: 0.2748
# --- Starting trial: run-5
# {'Lag': 53, 'Bia': True}
# session_num 5. r2: 0.86,  RMSE: 0.2748
# --- Starting trial: run-6
# {'Lag': 54, 'Bia': False}
# session_num 6. r2: 0.86,  RMSE: 0.2741
# --- Starting trial: run-7
# {'Lag': 54, 'Bia': True}
# session_num 7. r2: 0.86,  RMSE: 0.2741
# --- Starting trial: run-8
# {'Lag': 55, 'Bia': False}
# session_num 8. r2: 0.86,  RMSE: 0.2734
# --- Starting trial: run-9
# {'Lag': 55, 'Bia': True}
# session_num 9. r2: 0.86,  RMSE: 0.2734
# --- Starting trial: run-10
# {'Lag': 56, 'Bia': False}
# session_num 10. r2: 0.86,  RMSE: 0.2736
# --- Starting trial: run-11
# {'Lag': 56, 'Bia': True}
# session_num 11. r2: 0.86,  RMSE: 0.2736
# --- Starting trial: run-12
# {'Lag': 57, 'Bia': False}
# session_num 12. r2: 0.86,  RMSE: 0.2737
# --- Starting trial: run-13
# {'Lag': 57, 'Bia': True}
# session_num 13. r2: 0.86,  RMSE: 0.2737
# --- Starting trial: run-14
# {'Lag': 58, 'Bia': False}
# session_num 14. r2: 0.86,  RMSE: 0.2738
# --- Starting trial: run-15
# {'Lag': 58, 'Bia': True}
# session_num 15. r2: 0.86,  RMSE: 0.2738
# --- Starting trial: run-16
# {'Lag': 59, 'Bia': False}
# session_num 16. r2: 0.86,  RMSE: 0.2733
# --- Starting trial: run-17
# {'Lag': 59, 'Bia': True}
# session_num 17. r2: 0.86,  RMSE: 0.2733
# --- Starting trial: run-18
# {'Lag': 60, 'Bia': False}
# session_num 18. r2: 0.86,  RMSE: 0.2730
# --- Starting trial: run-19
# {'Lag': 60, 'Bia': True}
# session_num 19. r2: 0.86,  RMSE: 0.2730
# --- Starting trial: run-20
# {'Lag': 61, 'Bia': False}
# session_num 20. r2: 0.86,  RMSE: 0.2729
# --- Starting trial: run-21
# {'Lag': 61, 'Bia': True}
# session_num 21. r2: 0.86,  RMSE: 0.2730
# --- Starting trial: run-22
# {'Lag': 62, 'Bia': False}
# session_num 22. r2: 0.86,  RMSE: 0.2733
# --- Starting trial: run-23
# {'Lag': 62, 'Bia': True}
# session_num 23. r2: 0.86,  RMSE: 0.2733
# --- Starting trial: run-24
# {'Lag': 63, 'Bia': False}
# session_num 24. r2: 0.86,  RMSE: 0.2731
# --- Starting trial: run-25
# {'Lag': 63, 'Bia': True}
# session_num 25. r2: 0.86,  RMSE: 0.2731
# --- Starting trial: run-26
# {'Lag': 64, 'Bia': False}
# session_num 26. r2: 0.86,  RMSE: 0.2730
# --- Starting trial: run-27
# {'Lag': 64, 'Bia': True}
# session_num 27. r2: 0.86,  RMSE: 0.2730
# --- Starting trial: run-28
# {'Lag': 65, 'Bia': False}
# session_num 28. r2: 0.86,  RMSE: 0.2736
# --- Starting trial: run-29
# {'Lag': 65, 'Bia': True}
# session_num 29. r2: 0.86,  RMSE: 0.2736
# --- Starting trial: run-30
# {'Lag': 66, 'Bia': False}
# session_num 30. r2: 0.86,  RMSE: 0.2735
# --- Starting trial: run-31
# {'Lag': 66, 'Bia': True}
# session_num 31. r2: 0.86,  RMSE: 0.2735
# --- Starting trial: run-32
# {'Lag': 67, 'Bia': False}
# session_num 32. r2: 0.86,  RMSE: 0.2732
# --- Starting trial: run-33
# {'Lag': 67, 'Bia': True}
# session_num 33. r2: 0.86,  RMSE: 0.2732
# --- Starting trial: run-34
# {'Lag': 68, 'Bia': False}
# session_num 34. r2: 0.86,  RMSE: 0.2728
# --- Starting trial: run-35
# {'Lag': 68, 'Bia': True}
# session_num 35. r2: 0.86,  RMSE: 0.2728
# --- Starting trial: run-36
# {'Lag': 69, 'Bia': False}
# session_num 36. r2: 0.86,  RMSE: 0.2723
# --- Starting trial: run-37
# {'Lag': 69, 'Bia': True}
# session_num 37. r2: 0.86,  RMSE: 0.2723
# --- Starting trial: run-38
# {'Lag': 70, 'Bia': False}
# session_num 38. r2: 0.86,  RMSE: 0.2720
# --- Starting trial: run-39
# {'Lag': 70, 'Bia': True}
# session_num 39. r2: 0.86,  RMSE: 0.2720
# --- Starting trial: run-40
# {'Lag': 71, 'Bia': False}
# session_num 40. r2: 0.86,  RMSE: 0.2715
# --- Starting trial: run-41
# {'Lag': 71, 'Bia': True}
# session_num 41. r2: 0.86,  RMSE: 0.2715
# --- Starting trial: run-42
# {'Lag': 72, 'Bia': False}
# session_num 42. r2: 0.86,  RMSE: 0.2715
# --- Starting trial: run-43
# {'Lag': 72, 'Bia': True}
# session_num 43. r2: 0.86,  RMSE: 0.2715
# --- Starting trial: run-44
# {'Lag': 73, 'Bia': False}
# session_num 44. r2: 0.87,  RMSE: 0.2666
# --- Starting trial: run-45
# {'Lag': 73, 'Bia': True}
# session_num 45. r2: 0.87,  RMSE: 0.2666
# --- Starting trial: run-46
# {'Lag': 74, 'Bia': False}
# session_num 46. r2: 0.87,  RMSE: 0.2663
# --- Starting trial: run-47
# {'Lag': 74, 'Bia': True}
# session_num 47. r2: 0.87,  RMSE: 0.2663
# --- Starting trial: run-48
# {'Lag': 75, 'Bia': False}
# session_num 48. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-49
# {'Lag': 75, 'Bia': True}
# session_num 49. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-50
# {'Lag': 76, 'Bia': False}
# session_num 50. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-51
# {'Lag': 76, 'Bia': True}
# session_num 51. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-52
# {'Lag': 77, 'Bia': False}
# session_num 52. r2: 0.87,  RMSE: 0.2640
# --- Starting trial: run-53
# {'Lag': 77, 'Bia': True}
# session_num 53. r2: 0.87,  RMSE: 0.2640
# --- Starting trial: run-54
# {'Lag': 78, 'Bia': False}
# session_num 54. r2: 0.87,  RMSE: 0.2642
# --- Starting trial: run-55
# {'Lag': 78, 'Bia': True}
# session_num 55. r2: 0.87,  RMSE: 0.2642
# --- Starting trial: run-56
# {'Lag': 79, 'Bia': False}
# session_num 56. r2: 0.87,  RMSE: 0.2642
# --- Starting trial: run-57
# {'Lag': 79, 'Bia': True}
# session_num 57. r2: 0.87,  RMSE: 0.2642
# --- Starting trial: run-58
# {'Lag': 80, 'Bia': False}
# session_num 58. r2: 0.87,  RMSE: 0.2644
# --- Starting trial: run-59
# {'Lag': 80, 'Bia': True}
# session_num 59. r2: 0.87,  RMSE: 0.2644
# --- Starting trial: run-60
# {'Lag': 81, 'Bia': False}
# session_num 60. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-61
# {'Lag': 81, 'Bia': True}
# session_num 61. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-62
# {'Lag': 82, 'Bia': False}
# session_num 62. r2: 0.87,  RMSE: 0.2653
# --- Starting trial: run-63
# {'Lag': 82, 'Bia': True}
# session_num 63. r2: 0.87,  RMSE: 0.2653
# --- Starting trial: run-64
# {'Lag': 83, 'Bia': False}
# session_num 64. r2: 0.87,  RMSE: 0.2650
# --- Starting trial: run-65
# {'Lag': 83, 'Bia': True}
# session_num 65. r2: 0.87,  RMSE: 0.2650
# --- Starting trial: run-66
# {'Lag': 84, 'Bia': False}
# session_num 66. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-67
# {'Lag': 84, 'Bia': True}
# session_num 67. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-68
# {'Lag': 85, 'Bia': False}
# session_num 68. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-69
# {'Lag': 85, 'Bia': True}
# session_num 69. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-70
# {'Lag': 86, 'Bia': False}
# session_num 70. r2: 0.87,  RMSE: 0.2652
# --- Starting trial: run-71
# {'Lag': 86, 'Bia': True}
# session_num 71. r2: 0.87,  RMSE: 0.2652
# --- Starting trial: run-72
# {'Lag': 87, 'Bia': False}
# session_num 72. r2: 0.87,  RMSE: 0.2649
# --- Starting trial: run-73
# {'Lag': 87, 'Bia': True}
# session_num 73. r2: 0.87,  RMSE: 0.2649
# --- Starting trial: run-74
# {'Lag': 88, 'Bia': False}
# session_num 74. r2: 0.87,  RMSE: 0.2658
# --- Starting trial: run-75
# {'Lag': 88, 'Bia': True}
# session_num 75. r2: 0.87,  RMSE: 0.2658
# --- Starting trial: run-76
# {'Lag': 89, 'Bia': False}
# session_num 76. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-77
# {'Lag': 89, 'Bia': True}
# session_num 77. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-78
# {'Lag': 90, 'Bia': False}
# session_num 78. r2: 0.87,  RMSE: 0.2671
# --- Starting trial: run-79
# {'Lag': 90, 'Bia': True}
# session_num 79. r2: 0.87,  RMSE: 0.2671
# --- Starting trial: run-80
# {'Lag': 91, 'Bia': False}
# session_num 80. r2: 0.87,  RMSE: 0.2672
# --- Starting trial: run-81
# {'Lag': 91, 'Bia': True}
# session_num 81. r2: 0.87,  RMSE: 0.2672
# --- Starting trial: run-82
# {'Lag': 92, 'Bia': False}
# session_num 82. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-83
# {'Lag': 92, 'Bia': True}
# session_num 83. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-84
# {'Lag': 93, 'Bia': False}
# session_num 84. r2: 0.87,  RMSE: 0.2662
# --- Starting trial: run-85
# {'Lag': 93, 'Bia': True}
# session_num 85. r2: 0.87,  RMSE: 0.2662
# --- Starting trial: run-86
# {'Lag': 94, 'Bia': False}
# session_num 86. r2: 0.87,  RMSE: 0.2643
# --- Starting trial: run-87
# {'Lag': 94, 'Bia': True}
# session_num 87. r2: 0.87,  RMSE: 0.2643
# --- Starting trial: run-88
# {'Lag': 95, 'Bia': False}
# session_num 88. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-89
# {'Lag': 95, 'Bia': True}
# session_num 89. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-90
# {'Lag': 96, 'Bia': False}
# session_num 90. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-91
# {'Lag': 96, 'Bia': True}
# session_num 91. r2: 0.87,  RMSE: 0.2651
# --- Starting trial: run-92
# {'Lag': 97, 'Bia': False}
# session_num 92. r2: 0.87,  RMSE: 0.2679
# --- Starting trial: run-93
# {'Lag': 97, 'Bia': True}
# session_num 93. r2: 0.87,  RMSE: 0.2679
# --- Starting trial: run-94
# {'Lag': 98, 'Bia': False}
# session_num 94. r2: 0.87,  RMSE: 0.2685
# --- Starting trial: run-95
# {'Lag': 98, 'Bia': True}
# session_num 95. r2: 0.87,  RMSE: 0.2685
# --- Starting trial: run-96
# {'Lag': 99, 'Bia': False}
# session_num 96. r2: 0.87,  RMSE: 0.2685
# --- Starting trial: run-97
# {'Lag': 99, 'Bia': True}
# session_num 97. r2: 0.87,  RMSE: 0.2685
# --- Starting trial: run-98
# {'Lag': 100, 'Bia': False}
# session_num 98. r2: 0.87,  RMSE: 0.2687
# --- Starting trial: run-99
# {'Lag': 100, 'Bia': True}
# session_num 99. r2: 0.87,  RMSE: 0.2687
# --- Starting trial: run-100
# {'Lag': 101, 'Bia': False}
# session_num 100. r2: 0.87,  RMSE: 0.2688
# --- Starting trial: run-101
# {'Lag': 101, 'Bia': True}
# session_num 101. r2: 0.87,  RMSE: 0.2688
# --- Starting trial: run-102
# {'Lag': 102, 'Bia': False}
# session_num 102. r2: 0.87,  RMSE: 0.2689
# --- Starting trial: run-103
# {'Lag': 102, 'Bia': True}
# session_num 103. r2: 0.87,  RMSE: 0.2689
# --- Starting trial: run-104
# {'Lag': 103, 'Bia': False}
# session_num 104. r2: 0.87,  RMSE: 0.2686
# --- Starting trial: run-105
# {'Lag': 103, 'Bia': True}
# session_num 105. r2: 0.87,  RMSE: 0.2687
# --- Starting trial: run-106
# {'Lag': 104, 'Bia': False}
# session_num 106. r2: 0.87,  RMSE: 0.2685
# --- Starting trial: run-107
# {'Lag': 104, 'Bia': True}
# session_num 107. r2: 0.87,  RMSE: 0.2685
# --- Starting trial: run-108
# {'Lag': 105, 'Bia': False}
# session_num 108. r2: 0.87,  RMSE: 0.2690
# --- Starting trial: run-109
# {'Lag': 105, 'Bia': True}
# session_num 109. r2: 0.87,  RMSE: 0.2691
# --- Starting trial: run-110
# {'Lag': 106, 'Bia': False}
# session_num 110. r2: 0.87,  RMSE: 0.2692
# --- Starting trial: run-111
# {'Lag': 106, 'Bia': True}
# session_num 111. r2: 0.87,  RMSE: 0.2692
# --- Starting trial: run-112
# {'Lag': 107, 'Bia': False}
# session_num 112. r2: 0.87,  RMSE: 0.2693
# --- Starting trial: run-113
# {'Lag': 107, 'Bia': True}
# session_num 113. r2: 0.87,  RMSE: 0.2693
# --- Starting trial: run-114
# {'Lag': 108, 'Bia': False}
# session_num 114. r2: 0.87,  RMSE: 0.2696
# --- Starting trial: run-115
# {'Lag': 108, 'Bia': True}
# session_num 115. r2: 0.87,  RMSE: 0.2696
# --- Starting trial: run-116
# {'Lag': 109, 'Bia': False}
# session_num 116. r2: 0.87,  RMSE: 0.2697
# --- Starting trial: run-117
# {'Lag': 109, 'Bia': True}
# session_num 117. r2: 0.87,  RMSE: 0.2697
# --- Starting trial: run-118
# {'Lag': 110, 'Bia': False}
# session_num 118. r2: 0.87,  RMSE: 0.2699
# --- Starting trial: run-119
# {'Lag': 110, 'Bia': True}
# session_num 119. r2: 0.87,  RMSE: 0.2699
# --- Starting trial: run-120
# {'Lag': 111, 'Bia': False}
# session_num 120. r2: 0.87,  RMSE: 0.2698
# --- Starting trial: run-121
# {'Lag': 111, 'Bia': True}
# session_num 121. r2: 0.87,  RMSE: 0.2698
# --- Starting trial: run-122
# {'Lag': 112, 'Bia': False}
# session_num 122. r2: 0.87,  RMSE: 0.2695
# --- Starting trial: run-123
# {'Lag': 112, 'Bia': True}
# session_num 123. r2: 0.87,  RMSE: 0.2695
# --- Starting trial: run-124
# {'Lag': 113, 'Bia': False}
# session_num 124. r2: 0.87,  RMSE: 0.2695
# --- Starting trial: run-125
# {'Lag': 113, 'Bia': True}
# session_num 125. r2: 0.87,  RMSE: 0.2695
# --- Starting trial: run-126
# {'Lag': 114, 'Bia': False}
# session_num 126. r2: 0.87,  RMSE: 0.2694
# --- Starting trial: run-127
# {'Lag': 114, 'Bia': True}
# session_num 127. r2: 0.87,  RMSE: 0.2694
# --- Starting trial: run-128
# {'Lag': 115, 'Bia': False}
# session_num 128. r2: 0.87,  RMSE: 0.2695
# --- Starting trial: run-129
# {'Lag': 115, 'Bia': True}
# session_num 129. r2: 0.87,  RMSE: 0.2695
# --- Starting trial: run-130
# {'Lag': 116, 'Bia': False}
# session_num 130. r2: 0.87,  RMSE: 0.2691
# --- Starting trial: run-131
# {'Lag': 116, 'Bia': True}
# session_num 131. r2: 0.87,  RMSE: 0.2691
# --- Starting trial: run-132
# {'Lag': 117, 'Bia': False}
# session_num 132. r2: 0.87,  RMSE: 0.2678
# --- Starting trial: run-133
# {'Lag': 117, 'Bia': True}
# session_num 133. r2: 0.87,  RMSE: 0.2678
# --- Starting trial: run-134
# {'Lag': 118, 'Bia': False}
# session_num 134. r2: 0.87,  RMSE: 0.2662
# --- Starting trial: run-135
# {'Lag': 118, 'Bia': True}
# session_num 135. r2: 0.87,  RMSE: 0.2662
# --- Starting trial: run-136
# {'Lag': 119, 'Bia': False}
# session_num 136. r2: 0.87,  RMSE: 0.2659
# --- Starting trial: run-137
# {'Lag': 119, 'Bia': True}
# session_num 137. r2: 0.87,  RMSE: 0.2659
# --- Starting trial: run-138
# {'Lag': 120, 'Bia': False}
# session_num 138. r2: 0.87,  RMSE: 0.2661
# --- Starting trial: run-139
# {'Lag': 120, 'Bia': True}
# session_num 139. r2: 0.87,  RMSE: 0.2661
# --- Starting trial: run-140
# {'Lag': 121, 'Bia': False}
# session_num 140. r2: 0.87,  RMSE: 0.2658
# --- Starting trial: run-141
# {'Lag': 121, 'Bia': True}
# session_num 141. r2: 0.87,  RMSE: 0.2658
# --- Starting trial: run-142
# {'Lag': 122, 'Bia': False}
# session_num 142. r2: 0.87,  RMSE: 0.2662
# --- Starting trial: run-143
# {'Lag': 122, 'Bia': True}
# session_num 143. r2: 0.87,  RMSE: 0.2663
# --- Starting trial: run-144
# {'Lag': 123, 'Bia': False}
# session_num 144. r2: 0.87,  RMSE: 0.2663
# --- Starting trial: run-145
# {'Lag': 123, 'Bia': True}
# session_num 145. r2: 0.87,  RMSE: 0.2663
# --- Starting trial: run-146
# {'Lag': 124, 'Bia': False}
# session_num 146. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-147
# {'Lag': 124, 'Bia': True}
# session_num 147. r2: 0.87,  RMSE: 0.2665
# --- Starting trial: run-148
# {'Lag': 125, 'Bia': False}
# session_num 148. r2: 0.87,  RMSE: 0.2667
# --- Starting trial: run-149
# {'Lag': 125, 'Bia': True}
# session_num 149. r2: 0.87,  RMSE: 0.2668
# --- Starting trial: run-150
# {'Lag': 126, 'Bia': False}
# session_num 150. r2: 0.87,  RMSE: 0.2669
# --- Starting trial: run-151
# {'Lag': 126, 'Bia': True}
# session_num 151. r2: 0.87,  RMSE: 0.2669
# --- Starting trial: run-152
# {'Lag': 127, 'Bia': False}
# session_num 152. r2: 0.87,  RMSE: 0.2671
# --- Starting trial: run-153
# {'Lag': 127, 'Bia': True}
# session_num 153. r2: 0.87,  RMSE: 0.2671
# --- Starting trial: run-154
# {'Lag': 128, 'Bia': False}
# session_num 154. r2: 0.87,  RMSE: 0.2673
# --- Starting trial: run-155
# {'Lag': 128, 'Bia': True}
# session_num 155. r2: 0.87,  RMSE: 0.2673
# --- Starting trial: run-156
# {'Lag': 129, 'Bia': False}
# session_num 156. r2: 0.87,  RMSE: 0.2674
# --- Starting trial: run-157
# {'Lag': 129, 'Bia': True}
# session_num 157. r2: 0.87,  RMSE: 0.2674
# --- Starting trial: run-158
# {'Lag': 130, 'Bia': False}
# session_num 158. r2: 0.87,  RMSE: 0.2675
# --- Starting trial: run-159
# {'Lag': 130, 'Bia': True}
# session_num 159. r2: 0.87,  RMSE: 0.2675
# --- Starting trial: run-160
# {'Lag': 131, 'Bia': False}
# session_num 160. r2: 0.87,  RMSE: 0.2674
# --- Starting trial: run-161
# {'Lag': 131, 'Bia': True}
# session_num 161. r2: 0.87,  RMSE: 0.2674
# --- Starting trial: run-162
# {'Lag': 132, 'Bia': False}
# session_num 162. r2: 0.87,  RMSE: 0.2672
# --- Starting trial: run-163
# {'Lag': 132, 'Bia': True}
# session_num 163. r2: 0.87,  RMSE: 0.2672
# --- Starting trial: run-164
# {'Lag': 133, 'Bia': False}
# session_num 164. r2: 0.87,  RMSE: 0.2667
# --- Starting trial: run-165
# {'Lag': 133, 'Bia': True}
# session_num 165. r2: 0.87,  RMSE: 0.2667
# --- Starting trial: run-166
# {'Lag': 134, 'Bia': False}
# session_num 166. r2: 0.87,  RMSE: 0.2671
# --- Starting trial: run-167
# {'Lag': 134, 'Bia': True}
# session_num 167. r2: 0.87,  RMSE: 0.2671
# --- Starting trial: run-168
# {'Lag': 135, 'Bia': False}
# session_num 168. r2: 0.87,  RMSE: 0.2656
# --- Starting trial: run-169
# {'Lag': 135, 'Bia': True}
# session_num 169. r2: 0.87,  RMSE: 0.2656
# --- Starting trial: run-170
# {'Lag': 136, 'Bia': False}
# session_num 170. r2: 0.87,  RMSE: 0.2650
# --- Starting trial: run-171
# {'Lag': 136, 'Bia': True}
# session_num 171. r2: 0.87,  RMSE: 0.2650
# --- Starting trial: run-172
# {'Lag': 137, 'Bia': False}
# session_num 172. r2: 0.87,  RMSE: 0.2659
# --- Starting trial: run-173
# {'Lag': 137, 'Bia': True}
# session_num 173. r2: 0.87,  RMSE: 0.2659
# --- Starting trial: run-174
# {'Lag': 138, 'Bia': False}
# session_num 174. r2: 0.87,  RMSE: 0.2652
# --- Starting trial: run-175
# {'Lag': 138, 'Bia': True}
# session_num 175. r2: 0.87,  RMSE: 0.2652
# --- Starting trial: run-176
# {'Lag': 139, 'Bia': False}
# session_num 176. r2: 0.87,  RMSE: 0.2649
# --- Starting trial: run-177
# {'Lag': 139, 'Bia': True}
# session_num 177. r2: 0.87,  RMSE: 0.2649
# --- Starting trial: run-178
# {'Lag': 140, 'Bia': False}
# session_num 178. r2: 0.87,  RMSE: 0.2639
# --- Starting trial: run-179
# {'Lag': 140, 'Bia': True}
# session_num 179. r2: 0.87,  RMSE: 0.2639
# --- Starting trial: run-180
# {'Lag': 141, 'Bia': False}
# session_num 180. r2: 0.87,  RMSE: 0.2634
# --- Starting trial: run-181
# {'Lag': 141, 'Bia': True}
# session_num 181. r2: 0.87,  RMSE: 0.2634
# --- Starting trial: run-182
# {'Lag': 142, 'Bia': False}
# session_num 182. r2: 0.87,  RMSE: 0.2622
# --- Starting trial: run-183
# {'Lag': 142, 'Bia': True}
# session_num 183. r2: 0.87,  RMSE: 0.2622
# --- Starting trial: run-184
# {'Lag': 143, 'Bia': False}
# session_num 184. r2: 0.87,  RMSE: 0.2613
# --- Starting trial: run-185
# {'Lag': 143, 'Bia': True}
# session_num 185. r2: 0.87,  RMSE: 0.2614
# --- Starting trial: run-186
# {'Lag': 144, 'Bia': False}
# session_num 186. r2: 0.87,  RMSE: 0.2615
# --- Starting trial: run-187
# {'Lag': 144, 'Bia': True}
# session_num 187. r2: 0.87,  RMSE: 0.2615
# --- Starting trial: run-188
# {'Lag': 145, 'Bia': False}
# session_num 188. r2: 0.88,  RMSE: 0.2542
# --- Starting trial: run-189
# {'Lag': 145, 'Bia': True}
# session_num 189. r2: 0.88,  RMSE: 0.2542
# --- Starting trial: run-190
# {'Lag': 146, 'Bia': False}
# session_num 190. r2: 0.88,  RMSE: 0.2550
# --- Starting trial: run-191
# {'Lag': 146, 'Bia': True}
# session_num 191. r2: 0.88,  RMSE: 0.2550
# --- Starting trial: run-192
# {'Lag': 147, 'Bia': False}
# session_num 192. r2: 0.88,  RMSE: 0.2550
# --- Starting trial: run-193
# {'Lag': 147, 'Bia': True}
# session_num 193. r2: 0.88,  RMSE: 0.2550
# --- Starting trial: run-194
# {'Lag': 148, 'Bia': False}
# session_num 194. r2: 0.88,  RMSE: 0.2552
# --- Starting trial: run-195
# {'Lag': 148, 'Bia': True}
# session_num 195. r2: 0.88,  RMSE: 0.2552
# --- Starting trial: run-196
# {'Lag': 149, 'Bia': False}
# session_num 196. r2: 0.88,  RMSE: 0.2553
# --- Starting trial: run-197
# {'Lag': 149, 'Bia': True}
# session_num 197. r2: 0.88,  RMSE: 0.2553
# --- Starting trial: run-198
# {'Lag': 150, 'Bia': False}
# session_num 198. r2: 0.88,  RMSE: 0.2554
# --- Starting trial: run-199
# {'Lag': 150, 'Bia': True}
# session_num 199. r2: 0.88,  RMSE: 0.2554
# --- Starting trial: run-200
# {'Lag': 151, 'Bia': False}
# session_num 200. r2: 0.88,  RMSE: 0.2554
# --- Starting trial: run-201
# {'Lag': 151, 'Bia': True}
# session_num 201. r2: 0.88,  RMSE: 0.2554
# --- Starting trial: run-202
# {'Lag': 152, 'Bia': False}
# session_num 202. r2: 0.88,  RMSE: 0.2555
# --- Starting trial: run-203
# {'Lag': 152, 'Bia': True}
# session_num 203. r2: 0.88,  RMSE: 0.2555
# --- Starting trial: run-204
# {'Lag': 153, 'Bia': False}
# session_num 204. r2: 0.88,  RMSE: 0.2556
# --- Starting trial: run-205
# {'Lag': 153, 'Bia': True}
# session_num 205. r2: 0.88,  RMSE: 0.2557
# --- Starting trial: run-206
# {'Lag': 154, 'Bia': False}
# session_num 206. r2: 0.88,  RMSE: 0.2557
# --- Starting trial: run-207
# {'Lag': 154, 'Bia': True}
# session_num 207. r2: 0.88,  RMSE: 0.2557
# --- Starting trial: run-208
# {'Lag': 155, 'Bia': False}
# session_num 208. r2: 0.88,  RMSE: 0.2557
# --- Starting trial: run-209
# {'Lag': 155, 'Bia': True}
# session_num 209. r2: 0.88,  RMSE: 0.2557
# --- Starting trial: run-210
# {'Lag': 156, 'Bia': False}
# session_num 210. r2: 0.88,  RMSE: 0.2558
# --- Starting trial: run-211
# {'Lag': 156, 'Bia': True}
# session_num 211. r2: 0.88,  RMSE: 0.2558
# --- Starting trial: run-212
# {'Lag': 157, 'Bia': False}
# session_num 212. r2: 0.88,  RMSE: 0.2560
# --- Starting trial: run-213
# {'Lag': 157, 'Bia': True}
# session_num 213. r2: 0.88,  RMSE: 0.2560
# --- Starting trial: run-214
# {'Lag': 158, 'Bia': False}
# session_num 214. r2: 0.88,  RMSE: 0.2554
# --- Starting trial: run-215
# {'Lag': 158, 'Bia': True}
# session_num 215. r2: 0.88,  RMSE: 0.2554
# --- Starting trial: run-216
# {'Lag': 159, 'Bia': False}
# session_num 216. r2: 0.88,  RMSE: 0.2507
# --- Starting trial: run-217
# {'Lag': 159, 'Bia': True}
# session_num 217. r2: 0.88,  RMSE: 0.2507
# --- Starting trial: run-218
# {'Lag': 160, 'Bia': False}
# session_num 218. r2: 0.88,  RMSE: 0.2505
# --- Starting trial: run-219
# {'Lag': 160, 'Bia': True}
# session_num 219. r2: 0.88,  RMSE: 0.2505
# --- Starting trial: run-220
# {'Lag': 161, 'Bia': False}
# session_num 220. r2: 0.88,  RMSE: 0.2510
# --- Starting trial: run-221
# {'Lag': 161, 'Bia': True}
# session_num 221. r2: 0.88,  RMSE: 0.2510
# --- Starting trial: run-222
# {'Lag': 162, 'Bia': False}
# session_num 222. r2: 0.88,  RMSE: 0.2509
# --- Starting trial: run-223
# {'Lag': 162, 'Bia': True}
# session_num 223. r2: 0.88,  RMSE: 0.2509
# --- Starting trial: run-224
# {'Lag': 163, 'Bia': False}
# session_num 224. r2: 0.88,  RMSE: 0.2511
# --- Starting trial: run-225
# {'Lag': 163, 'Bia': True}
# session_num 225. r2: 0.88,  RMSE: 0.2512
# --- Starting trial: run-226
# {'Lag': 164, 'Bia': False}
# session_num 226. r2: 0.88,  RMSE: 0.2509
# --- Starting trial: run-227
# {'Lag': 164, 'Bia': True}
# session_num 227. r2: 0.88,  RMSE: 0.2509
# --- Starting trial: run-228
# {'Lag': 165, 'Bia': False}
# session_num 228. r2: 0.88,  RMSE: 0.2503
# --- Starting trial: run-229
# {'Lag': 165, 'Bia': True}
# session_num 229. r2: 0.88,  RMSE: 0.2504
# --- Starting trial: run-230
# {'Lag': 166, 'Bia': False}
# session_num 230. r2: 0.88,  RMSE: 0.2504
# --- Starting trial: run-231
# {'Lag': 166, 'Bia': True}
# session_num 231. r2: 0.88,  RMSE: 0.2504
# --- Starting trial: run-232
# {'Lag': 167, 'Bia': False}
# session_num 232. r2: 0.88,  RMSE: 0.2504
# --- Starting trial: run-233
# {'Lag': 167, 'Bia': True}
# session_num 233. r2: 0.88,  RMSE: 0.2505
# --- Starting trial: run-234
# {'Lag': 168, 'Bia': False}
# session_num 234. r2: 0.88,  RMSE: 0.2505
# --- Starting trial: run-235
# {'Lag': 168, 'Bia': True}
# session_num 235. r2: 0.88,  RMSE: 0.2505
# --- Starting trial: run-236
# {'Lag': 169, 'Bia': False}
# session_num 236. r2: 0.89,  RMSE: 0.2456
# --- Starting trial: run-237
# {'Lag': 169, 'Bia': True}
# session_num 237. r2: 0.89,  RMSE: 0.2456
# --- Starting trial: run-238
# {'Lag': 170, 'Bia': False}
# session_num 238. r2: 0.89,  RMSE: 0.2462
# --- Starting trial: run-239
# {'Lag': 170, 'Bia': True}
# session_num 239. r2: 0.89,  RMSE: 0.2462
# --- Starting trial: run-240
# {'Lag': 171, 'Bia': False}
# session_num 240. r2: 0.89,  RMSE: 0.2460
# --- Starting trial: run-241
# {'Lag': 171, 'Bia': True}
# session_num 241. r2: 0.89,  RMSE: 0.2461
# --- Starting trial: run-242
# {'Lag': 172, 'Bia': False}
# session_num 242. r2: 0.89,  RMSE: 0.2464
# --- Starting trial: run-243
# {'Lag': 172, 'Bia': True}
# session_num 243. r2: 0.89,  RMSE: 0.2465
# --- Starting trial: run-244
# {'Lag': 173, 'Bia': False}
# session_num 244. r2: 0.89,  RMSE: 0.2464
# --- Starting trial: run-245
# {'Lag': 173, 'Bia': True}
# session_num 245. r2: 0.89,  RMSE: 0.2465
# --- Starting trial: run-246
# {'Lag': 174, 'Bia': False}
# session_num 246. r2: 0.89,  RMSE: 0.2466
# --- Starting trial: run-247
# {'Lag': 174, 'Bia': True}
# session_num 247. r2: 0.89,  RMSE: 0.2467
# --- Starting trial: run-248
# {'Lag': 175, 'Bia': False}
# session_num 248. r2: 0.88,  RMSE: 0.2468
# --- Starting trial: run-249
# {'Lag': 175, 'Bia': True}
# session_num 249. r2: 0.88,  RMSE: 0.2468
# --- Starting trial: run-250
# {'Lag': 176, 'Bia': False}
# session_num 250. r2: 0.88,  RMSE: 0.2476
# --- Starting trial: run-251
# {'Lag': 176, 'Bia': True}
# session_num 251. r2: 0.88,  RMSE: 0.2476
# --- Starting trial: run-252
# {'Lag': 177, 'Bia': False}
# session_num 252. r2: 0.88,  RMSE: 0.2477
# --- Starting trial: run-253
# {'Lag': 177, 'Bia': True}
# session_num 253. r2: 0.88,  RMSE: 0.2477
# --- Starting trial: run-254
# {'Lag': 178, 'Bia': False}
# session_num 254. r2: 0.88,  RMSE: 0.2479
# --- Starting trial: run-255
# {'Lag': 178, 'Bia': True}
# session_num 255. r2: 0.88,  RMSE: 0.2480
# --- Starting trial: run-256
# {'Lag': 179, 'Bia': False}
# session_num 256. r2: 0.88,  RMSE: 0.2479
# --- Starting trial: run-257
# {'Lag': 179, 'Bia': True}
# session_num 257. r2: 0.88,  RMSE: 0.2479
# --- Starting trial: run-258
# {'Lag': 180, 'Bia': False}
# session_num 258. r2: 0.88,  RMSE: 0.2482
# --- Starting trial: run-259
# {'Lag': 180, 'Bia': True}
# session_num 259. r2: 0.88,  RMSE: 0.2482
# --- Starting trial: run-260
# {'Lag': 181, 'Bia': False}
# session_num 260. r2: 0.88,  RMSE: 0.2484
# --- Starting trial: run-261
# {'Lag': 181, 'Bia': True}
# session_num 261. r2: 0.88,  RMSE: 0.2485
# --- Starting trial: run-262
# {'Lag': 182, 'Bia': False}
# session_num 262. r2: 0.88,  RMSE: 0.2485
# --- Starting trial: run-263
# {'Lag': 182, 'Bia': True}
# session_num 263. r2: 0.88,  RMSE: 0.2485
# --- Starting trial: run-264
# {'Lag': 183, 'Bia': False}
# session_num 264. r2: 0.88,  RMSE: 0.2490
# --- Starting trial: run-265
# {'Lag': 183, 'Bia': True}
# session_num 265. r2: 0.88,  RMSE: 0.2491
# --- Starting trial: run-266
# {'Lag': 184, 'Bia': False}
# session_num 266. r2: 0.88,  RMSE: 0.2487
# --- Starting trial: run-267
# {'Lag': 184, 'Bia': True}
# session_num 267. r2: 0.88,  RMSE: 0.2487
# --- Starting trial: run-268
# {'Lag': 185, 'Bia': False}
# session_num 268. r2: 0.88,  RMSE: 0.2488
# --- Starting trial: run-269
# {'Lag': 185, 'Bia': True}
# session_num 269. r2: 0.88,  RMSE: 0.2488
# --- Starting trial: run-270
# {'Lag': 186, 'Bia': False}
# session_num 270. r2: 0.88,  RMSE: 0.2490
# --- Starting trial: run-271
# {'Lag': 186, 'Bia': True}
# session_num 271. r2: 0.88,  RMSE: 0.2490
# --- Starting trial: run-272
# {'Lag': 187, 'Bia': False}
# session_num 272. r2: 0.88,  RMSE: 0.2492
# --- Starting trial: run-273
# {'Lag': 187, 'Bia': True}
# session_num 273. r2: 0.88,  RMSE: 0.2492
# --- Starting trial: run-274
# {'Lag': 188, 'Bia': False}
# session_num 274. r2: 0.88,  RMSE: 0.2489
# --- Starting trial: run-275
# {'Lag': 188, 'Bia': True}
# session_num 275. r2: 0.88,  RMSE: 0.2490
# --- Starting trial: run-276
# {'Lag': 189, 'Bia': False}
# session_num 276. r2: 0.88,  RMSE: 0.2477
# --- Starting trial: run-277
# {'Lag': 189, 'Bia': True}
# session_num 277. r2: 0.88,  RMSE: 0.2477
# --- Starting trial: run-278
# {'Lag': 190, 'Bia': False}
# session_num 278. r2: 0.88,  RMSE: 0.2464
# --- Starting trial: run-279
# {'Lag': 190, 'Bia': True}
# session_num 279. r2: 0.88,  RMSE: 0.2465
# --- Starting trial: run-280
# {'Lag': 191, 'Bia': False}
# session_num 280. r2: 0.88,  RMSE: 0.2461
# --- Starting trial: run-281
# {'Lag': 191, 'Bia': True}
# session_num 281. r2: 0.88,  RMSE: 0.2462
# --- Starting trial: run-282
# {'Lag': 192, 'Bia': False}
# session_num 282. r2: 0.88,  RMSE: 0.2462
# --- Starting trial: run-283
# {'Lag': 192, 'Bia': True}
# session_num 283. r2: 0.88,  RMSE: 0.2463
# --- Starting trial: run-284
# {'Lag': 193, 'Bia': False}
# session_num 284. r2: 0.88,  RMSE: 0.2471
# --- Starting trial: run-285
# {'Lag': 193, 'Bia': True}
# session_num 285. r2: 0.88,  RMSE: 0.2471
# --- Starting trial: run-286
# {'Lag': 194, 'Bia': False}
# session_num 286. r2: 0.88,  RMSE: 0.2474
# --- Starting trial: run-287
# {'Lag': 194, 'Bia': True}
# session_num 287. r2: 0.88,  RMSE: 0.2474
# --- Starting trial: run-288
# {'Lag': 195, 'Bia': False}
# session_num 288. r2: 0.88,  RMSE: 0.2476
# --- Starting trial: run-289
# {'Lag': 195, 'Bia': True}
# session_num 289. r2: 0.88,  RMSE: 0.2476
# --- Starting trial: run-290
# {'Lag': 196, 'Bia': False}
# session_num 290. r2: 0.88,  RMSE: 0.2478
# --- Starting trial: run-291
# {'Lag': 196, 'Bia': True}
# session_num 291. r2: 0.88,  RMSE: 0.2478
# --- Starting trial: run-292
# {'Lag': 197, 'Bia': False}
# session_num 292. r2: 0.88,  RMSE: 0.2480
# --- Starting trial: run-293
# {'Lag': 197, 'Bia': True}
# session_num 293. r2: 0.88,  RMSE: 0.2480
# --- Starting trial: run-294
# {'Lag': 198, 'Bia': False}
# session_num 294. r2: 0.88,  RMSE: 0.2481
# --- Starting trial: run-295
# {'Lag': 198, 'Bia': True}
# session_num 295. r2: 0.88,  RMSE: 0.2481
# --- Starting trial: run-296
# {'Lag': 199, 'Bia': False}
# session_num 296. r2: 0.88,  RMSE: 0.2482
# --- Starting trial: run-297
# {'Lag': 199, 'Bia': True}
# session_num 297. r2: 0.88,  RMSE: 0.2483
# --- Starting trial: run-298
# {'Lag': 200, 'Bia': False}
# session_num 298. r2: 0.88,  RMSE: 0.2486
# --- Starting trial: run-299
# {'Lag': 200, 'Bia': True}
# session_num 299. r2: 0.88,  RMSE: 0.2486
# --- Starting trial: run-300
# {'Lag': 201, 'Bia': False}
# session_num 300. r2: 0.88,  RMSE: 0.2486
# --- Starting trial: run-301
# {'Lag': 201, 'Bia': True}
# session_num 301. r2: 0.88,  RMSE: 0.2487
# --- Starting trial: run-302
# {'Lag': 202, 'Bia': False}
# session_num 302. r2: 0.88,  RMSE: 0.2487
# --- Starting trial: run-303
# {'Lag': 202, 'Bia': True}
# session_num 303. r2: 0.88,  RMSE: 0.2488
# --- Starting trial: run-304
# {'Lag': 203, 'Bia': False}
# session_num 304. r2: 0.88,  RMSE: 0.2488
# --- Starting trial: run-305
# {'Lag': 203, 'Bia': True}
# session_num 305. r2: 0.88,  RMSE: 0.2488
# --- Starting trial: run-306
# {'Lag': 204, 'Bia': False}
# session_num 306. r2: 0.88,  RMSE: 0.2489
# --- Starting trial: run-307
# {'Lag': 204, 'Bia': True}
# session_num 307. r2: 0.88,  RMSE: 0.2489
# --- Starting trial: run-308
# {'Lag': 205, 'Bia': False}
# session_num 308. r2: 0.88,  RMSE: 0.2453
# --- Starting trial: run-309
# {'Lag': 205, 'Bia': True}
# session_num 309. r2: 0.88,  RMSE: 0.2453
# --- Starting trial: run-310
# {'Lag': 206, 'Bia': False}
# session_num 310. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-311
# {'Lag': 206, 'Bia': True}
# session_num 311. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-312
# {'Lag': 207, 'Bia': False}
# session_num 312. r2: 0.88,  RMSE: 0.2449
# --- Starting trial: run-313
# {'Lag': 207, 'Bia': True}
# session_num 313. r2: 0.88,  RMSE: 0.2449
# --- Starting trial: run-314
# {'Lag': 208, 'Bia': False}
# session_num 314. r2: 0.88,  RMSE: 0.2449
# --- Starting trial: run-315
# {'Lag': 208, 'Bia': True}
# session_num 315. r2: 0.88,  RMSE: 0.2450
# --- Starting trial: run-316
# {'Lag': 209, 'Bia': False}
# session_num 316. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-317
# {'Lag': 209, 'Bia': True}
# session_num 317. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-318
# {'Lag': 210, 'Bia': False}
# session_num 318. r2: 0.88,  RMSE: 0.2453
# --- Starting trial: run-319
# {'Lag': 210, 'Bia': True}
# session_num 319. r2: 0.88,  RMSE: 0.2453
# --- Starting trial: run-320
# {'Lag': 211, 'Bia': False}
# session_num 320. r2: 0.88,  RMSE: 0.2454
# --- Starting trial: run-321
# {'Lag': 211, 'Bia': True}
# session_num 321. r2: 0.88,  RMSE: 0.2454
# --- Starting trial: run-322
# {'Lag': 212, 'Bia': False}
# session_num 322. r2: 0.88,  RMSE: 0.2444
# --- Starting trial: run-323
# {'Lag': 212, 'Bia': True}
# session_num 323. r2: 0.88,  RMSE: 0.2445
# --- Starting trial: run-324
# {'Lag': 213, 'Bia': False}
# session_num 324. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-325
# {'Lag': 213, 'Bia': True}
# session_num 325. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-326
# {'Lag': 214, 'Bia': False}
# session_num 326. r2: 0.88,  RMSE: 0.2436
# --- Starting trial: run-327
# {'Lag': 214, 'Bia': True}
# session_num 327. r2: 0.88,  RMSE: 0.2437
# --- Starting trial: run-328
# {'Lag': 215, 'Bia': False}
# session_num 328. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-329
# {'Lag': 215, 'Bia': True}
# session_num 329. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-330
# {'Lag': 216, 'Bia': False}
# session_num 330. r2: 0.88,  RMSE: 0.2437
# --- Starting trial: run-331
# {'Lag': 216, 'Bia': True}
# session_num 331. r2: 0.88,  RMSE: 0.2437
# --- Starting trial: run-332
# {'Lag': 217, 'Bia': False}
# session_num 332. r2: 0.88,  RMSE: 0.2440
# --- Starting trial: run-333
# {'Lag': 217, 'Bia': True}
# session_num 333. r2: 0.88,  RMSE: 0.2440
# --- Starting trial: run-334
# {'Lag': 218, 'Bia': False}
# session_num 334. r2: 0.88,  RMSE: 0.2440
# --- Starting trial: run-335
# {'Lag': 218, 'Bia': True}
# session_num 335. r2: 0.88,  RMSE: 0.2440
# --- Starting trial: run-336
# {'Lag': 219, 'Bia': False}
# session_num 336. r2: 0.88,  RMSE: 0.2441
# --- Starting trial: run-337
# {'Lag': 219, 'Bia': True}
# session_num 337. r2: 0.88,  RMSE: 0.2441
# --- Starting trial: run-338
# {'Lag': 220, 'Bia': False}
# session_num 338. r2: 0.88,  RMSE: 0.2439
# --- Starting trial: run-339
# {'Lag': 220, 'Bia': True}
# session_num 339. r2: 0.88,  RMSE: 0.2440
# --- Starting trial: run-340
# {'Lag': 221, 'Bia': False}
# session_num 340. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-341
# {'Lag': 221, 'Bia': True}
# session_num 341. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-342
# {'Lag': 222, 'Bia': False}
# session_num 342. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-343
# {'Lag': 222, 'Bia': True}
# session_num 343. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-344
# {'Lag': 223, 'Bia': False}
# session_num 344. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-345
# {'Lag': 223, 'Bia': True}
# session_num 345. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-346
# {'Lag': 224, 'Bia': False}
# session_num 346. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-347
# {'Lag': 224, 'Bia': True}
# session_num 347. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-348
# {'Lag': 225, 'Bia': False}
# session_num 348. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-349
# {'Lag': 225, 'Bia': True}
# session_num 349. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-350
# {'Lag': 226, 'Bia': False}
# session_num 350. r2: 0.88,  RMSE: 0.2437
# --- Starting trial: run-351
# {'Lag': 226, 'Bia': True}
# session_num 351. r2: 0.88,  RMSE: 0.2437
# --- Starting trial: run-352
# {'Lag': 227, 'Bia': False}
# session_num 352. r2: 0.88,  RMSE: 0.2439
# --- Starting trial: run-353
# {'Lag': 227, 'Bia': True}
# session_num 353. r2: 0.88,  RMSE: 0.2439
# --- Starting trial: run-354
# {'Lag': 228, 'Bia': False}
# session_num 354. r2: 0.88,  RMSE: 0.2442
# --- Starting trial: run-355
# {'Lag': 228, 'Bia': True}
# session_num 355. r2: 0.88,  RMSE: 0.2442
# --- Starting trial: run-356
# {'Lag': 229, 'Bia': False}
# session_num 356. r2: 0.88,  RMSE: 0.2413
# --- Starting trial: run-357
# {'Lag': 229, 'Bia': True}
# session_num 357. r2: 0.88,  RMSE: 0.2414
# --- Starting trial: run-358
# {'Lag': 230, 'Bia': False}
# session_num 358. r2: 0.88,  RMSE: 0.2412
# --- Starting trial: run-359
# {'Lag': 230, 'Bia': True}
# session_num 359. r2: 0.88,  RMSE: 0.2412
# --- Starting trial: run-360
# {'Lag': 231, 'Bia': False}
# session_num 360. r2: 0.88,  RMSE: 0.2414
# --- Starting trial: run-361
# {'Lag': 231, 'Bia': True}
# session_num 361. r2: 0.88,  RMSE: 0.2415
# --- Starting trial: run-362
# {'Lag': 232, 'Bia': False}
# session_num 362. r2: 0.88,  RMSE: 0.2416
# --- Starting trial: run-363
# {'Lag': 232, 'Bia': True}
# session_num 363. r2: 0.88,  RMSE: 0.2417
# --- Starting trial: run-364
# {'Lag': 233, 'Bia': False}
# session_num 364. r2: 0.88,  RMSE: 0.2418
# --- Starting trial: run-365
# {'Lag': 233, 'Bia': True}
# session_num 365. r2: 0.88,  RMSE: 0.2418
# --- Starting trial: run-366
# {'Lag': 234, 'Bia': False}
# session_num 366. r2: 0.88,  RMSE: 0.2420
# --- Starting trial: run-367
# {'Lag': 234, 'Bia': True}
# session_num 367. r2: 0.88,  RMSE: 0.2420
# --- Starting trial: run-368
# {'Lag': 235, 'Bia': False}
# session_num 368. r2: 0.88,  RMSE: 0.2427
# --- Starting trial: run-369
# {'Lag': 235, 'Bia': True}
# session_num 369. r2: 0.88,  RMSE: 0.2427
# --- Starting trial: run-370
# {'Lag': 236, 'Bia': False}
# session_num 370. r2: 0.88,  RMSE: 0.2427
# --- Starting trial: run-371
# {'Lag': 236, 'Bia': True}
# session_num 371. r2: 0.88,  RMSE: 0.2427
# --- Starting trial: run-372
# {'Lag': 237, 'Bia': False}
# session_num 372. r2: 0.88,  RMSE: 0.2429
# --- Starting trial: run-373
# {'Lag': 237, 'Bia': True}
# session_num 373. r2: 0.88,  RMSE: 0.2429
# --- Starting trial: run-374
# {'Lag': 238, 'Bia': False}
# session_num 374. r2: 0.88,  RMSE: 0.2421
# --- Starting trial: run-375
# {'Lag': 238, 'Bia': True}
# session_num 375. r2: 0.88,  RMSE: 0.2422
# --- Starting trial: run-376
# {'Lag': 239, 'Bia': False}
# session_num 376. r2: 0.88,  RMSE: 0.2427
# --- Starting trial: run-377
# {'Lag': 239, 'Bia': True}
# session_num 377. r2: 0.88,  RMSE: 0.2427
# --- Starting trial: run-378
# {'Lag': 240, 'Bia': False}
# session_num 378. r2: 0.88,  RMSE: 0.2427
# --- Starting trial: run-379
# {'Lag': 240, 'Bia': True}
# session_num 379. r2: 0.88,  RMSE: 0.2428
# --- Starting trial: run-380
# {'Lag': 241, 'Bia': False}
# session_num 380. r2: 0.88,  RMSE: 0.2430
# --- Starting trial: run-381
# {'Lag': 241, 'Bia': True}
# session_num 381. r2: 0.88,  RMSE: 0.2431
# --- Starting trial: run-382
# {'Lag': 242, 'Bia': False}
# session_num 382. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-383
# {'Lag': 242, 'Bia': True}
# session_num 383. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-384
# {'Lag': 243, 'Bia': False}
# session_num 384. r2: 0.88,  RMSE: 0.2436
# --- Starting trial: run-385
# {'Lag': 243, 'Bia': True}
# session_num 385. r2: 0.88,  RMSE: 0.2436
# --- Starting trial: run-386
# {'Lag': 244, 'Bia': False}
# session_num 386. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-387
# {'Lag': 244, 'Bia': True}
# session_num 387. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-388
# {'Lag': 245, 'Bia': False}
# session_num 388. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-389
# {'Lag': 245, 'Bia': True}
# session_num 389. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-390
# {'Lag': 246, 'Bia': False}
# session_num 390. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-391
# {'Lag': 246, 'Bia': True}
# session_num 391. r2: 0.88,  RMSE: 0.2436
# --- Starting trial: run-392
# {'Lag': 247, 'Bia': False}
# session_num 392. r2: 0.88,  RMSE: 0.2431
# --- Starting trial: run-393
# {'Lag': 247, 'Bia': True}
# session_num 393. r2: 0.88,  RMSE: 0.2432
# --- Starting trial: run-394
# {'Lag': 248, 'Bia': False}
# session_num 394. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-395
# {'Lag': 248, 'Bia': True}
# session_num 395. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-396
# {'Lag': 249, 'Bia': False}
# session_num 396. r2: 0.88,  RMSE: 0.2436
# --- Starting trial: run-397
# {'Lag': 249, 'Bia': True}
# session_num 397. r2: 0.88,  RMSE: 0.2436
# --- Starting trial: run-398
# {'Lag': 250, 'Bia': False}
# session_num 398. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-399
# {'Lag': 250, 'Bia': True}
# session_num 399. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-400
# {'Lag': 251, 'Bia': False}
# session_num 400. r2: 0.88,  RMSE: 0.2437
# --- Starting trial: run-401
# {'Lag': 251, 'Bia': True}
# session_num 401. r2: 0.88,  RMSE: 0.2437
# --- Starting trial: run-402
# {'Lag': 252, 'Bia': False}
# session_num 402. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-403
# {'Lag': 252, 'Bia': True}
# session_num 403. r2: 0.88,  RMSE: 0.2438
# --- Starting trial: run-404
# {'Lag': 253, 'Bia': False}
# session_num 404. r2: 0.88,  RMSE: 0.2440
# --- Starting trial: run-405
# {'Lag': 253, 'Bia': True}
# session_num 405. r2: 0.88,  RMSE: 0.2441
# --- Starting trial: run-406
# {'Lag': 254, 'Bia': False}
# session_num 406. r2: 0.88,  RMSE: 0.2441
# --- Starting trial: run-407
# {'Lag': 254, 'Bia': True}
# session_num 407. r2: 0.88,  RMSE: 0.2441
# --- Starting trial: run-408
# {'Lag': 255, 'Bia': False}
# session_num 408. r2: 0.88,  RMSE: 0.2443
# --- Starting trial: run-409
# {'Lag': 255, 'Bia': True}
# session_num 409. r2: 0.88,  RMSE: 0.2443
# --- Starting trial: run-410
# {'Lag': 256, 'Bia': False}
# session_num 410. r2: 0.88,  RMSE: 0.2445
# --- Starting trial: run-411
# {'Lag': 256, 'Bia': True}
# session_num 411. r2: 0.88,  RMSE: 0.2445
# --- Starting trial: run-412
# {'Lag': 257, 'Bia': False}
# session_num 412. r2: 0.88,  RMSE: 0.2447
# --- Starting trial: run-413
# {'Lag': 257, 'Bia': True}
# session_num 413. r2: 0.88,  RMSE: 0.2447
# --- Starting trial: run-414
# {'Lag': 258, 'Bia': False}
# session_num 414. r2: 0.88,  RMSE: 0.2443
# --- Starting trial: run-415
# {'Lag': 258, 'Bia': True}
# session_num 415. r2: 0.88,  RMSE: 0.2443
# --- Starting trial: run-416
# {'Lag': 259, 'Bia': False}
# session_num 416. r2: 0.88,  RMSE: 0.2445
# --- Starting trial: run-417
# {'Lag': 259, 'Bia': True}
# session_num 417. r2: 0.88,  RMSE: 0.2445
# --- Starting trial: run-418
# {'Lag': 260, 'Bia': False}
# session_num 418. r2: 0.88,  RMSE: 0.2442
# --- Starting trial: run-419
# {'Lag': 260, 'Bia': True}
# session_num 419. r2: 0.88,  RMSE: 0.2442
# --- Starting trial: run-420
# {'Lag': 261, 'Bia': False}
# session_num 420. r2: 0.88,  RMSE: 0.2434
# --- Starting trial: run-421
# {'Lag': 261, 'Bia': True}
# session_num 421. r2: 0.88,  RMSE: 0.2435
# --- Starting trial: run-422
# {'Lag': 262, 'Bia': False}
# session_num 422. r2: 0.88,  RMSE: 0.2428
# --- Starting trial: run-423
# {'Lag': 262, 'Bia': True}
# session_num 423. r2: 0.88,  RMSE: 0.2428
# --- Starting trial: run-424
# {'Lag': 263, 'Bia': False}
# session_num 424. r2: 0.88,  RMSE: 0.2430
# --- Starting trial: run-425
# {'Lag': 263, 'Bia': True}
# session_num 425. r2: 0.88,  RMSE: 0.2430
# --- Starting trial: run-426
# {'Lag': 264, 'Bia': False}
# session_num 426. r2: 0.88,  RMSE: 0.2432
# --- Starting trial: run-427
# {'Lag': 264, 'Bia': True}
# session_num 427. r2: 0.88,  RMSE: 0.2432
# --- Starting trial: run-428
# {'Lag': 265, 'Bia': False}
# session_num 428. r2: 0.88,  RMSE: 0.2444
# --- Starting trial: run-429
# {'Lag': 265, 'Bia': True}
# session_num 429. r2: 0.88,  RMSE: 0.2444
# --- Starting trial: run-430
# {'Lag': 266, 'Bia': False}
# session_num 430. r2: 0.88,  RMSE: 0.2449
# --- Starting trial: run-431
# {'Lag': 266, 'Bia': True}
# session_num 431. r2: 0.88,  RMSE: 0.2450
# --- Starting trial: run-432
# {'Lag': 267, 'Bia': False}
# session_num 432. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-433
# {'Lag': 267, 'Bia': True}
# session_num 433. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-434
# {'Lag': 268, 'Bia': False}
# session_num 434. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-435
# {'Lag': 268, 'Bia': True}
# session_num 435. r2: 0.88,  RMSE: 0.2452
# --- Starting trial: run-436
# {'Lag': 269, 'Bia': False}
# session_num 436. r2: 0.88,  RMSE: 0.2453
# --- Starting trial: run-437
# {'Lag': 269, 'Bia': True}
# session_num 437. r2: 0.88,  RMSE: 0.2454
# --- Starting trial: run-438
# {'Lag': 270, 'Bia': False}
# session_num 438. r2: 0.87,  RMSE: 0.2453
# --- Starting trial: run-439
# {'Lag': 270, 'Bia': True}
# session_num 439. r2: 0.87,  RMSE: 0.2453
# --- Starting trial: run-440
# {'Lag': 271, 'Bia': False}
# session_num 440. r2: 0.87,  RMSE: 0.2454
# --- Starting trial: run-441
# {'Lag': 271, 'Bia': True}
# session_num 441. r2: 0.87,  RMSE: 0.2455
# --- Starting trial: run-442
# {'Lag': 272, 'Bia': False}
# session_num 442. r2: 0.87,  RMSE: 0.2456
# --- Starting trial: run-443
# {'Lag': 272, 'Bia': True}
# session_num 443. r2: 0.87,  RMSE: 0.2456
# --- Starting trial: run-444
# {'Lag': 273, 'Bia': False}
# session_num 444. r2: 0.87,  RMSE: 0.2452
# --- Starting trial: run-445
# {'Lag': 273, 'Bia': True}
# session_num 445. r2: 0.87,  RMSE: 0.2452
# --- Starting trial: run-446
# {'Lag': 274, 'Bia': False}
# session_num 446. r2: 0.87,  RMSE: 0.2450
# --- Starting trial: run-447
# {'Lag': 274, 'Bia': True}
# session_num 447. r2: 0.87,  RMSE: 0.2451
# --- Starting trial: run-448
# {'Lag': 275, 'Bia': False}
# session_num 448. r2: 0.87,  RMSE: 0.2456
# --- Starting trial: run-449
# {'Lag': 275, 'Bia': True}
# session_num 449. r2: 0.87,  RMSE: 0.2456
# --- Starting trial: run-450
# {'Lag': 276, 'Bia': False}
# session_num 450. r2: 0.87,  RMSE: 0.2459
# --- Starting trial: run-451
# {'Lag': 276, 'Bia': True}
# session_num 451. r2: 0.87,  RMSE: 0.2459
# --- Starting trial: run-452
# {'Lag': 277, 'Bia': False}
# session_num 452. r2: 0.87,  RMSE: 0.2431
# --- Starting trial: run-453
# {'Lag': 277, 'Bia': True}
# session_num 453. r2: 0.87,  RMSE: 0.2431
# --- Starting trial: run-454
# {'Lag': 278, 'Bia': False}
# session_num 454. r2: 0.87,  RMSE: 0.2433
# --- Starting trial: run-455
# {'Lag': 278, 'Bia': True}
# session_num 455. r2: 0.87,  RMSE: 0.2433
# --- Starting trial: run-456
# {'Lag': 279, 'Bia': False}
# session_num 456. r2: 0.87,  RMSE: 0.2437
# --- Starting trial: run-457
# {'Lag': 279, 'Bia': True}
# session_num 457. r2: 0.87,  RMSE: 0.2438
# --- Starting trial: run-458
# {'Lag': 280, 'Bia': False}
# session_num 458. r2: 0.87,  RMSE: 0.2440
# --- Starting trial: run-459
# {'Lag': 280, 'Bia': True}
# session_num 459. r2: 0.87,  RMSE: 0.2441
# --- Starting trial: run-460
# {'Lag': 281, 'Bia': False}
# session_num 460. r2: 0.87,  RMSE: 0.2442
# --- Starting trial: run-461
# {'Lag': 281, 'Bia': True}
# session_num 461. r2: 0.87,  RMSE: 0.2442
# --- Starting trial: run-462
# {'Lag': 282, 'Bia': False}
# session_num 462. r2: 0.87,  RMSE: 0.2446
# --- Starting trial: run-463
# {'Lag': 282, 'Bia': True}
# session_num 463. r2: 0.87,  RMSE: 0.2446
# --- Starting trial: run-464
# {'Lag': 283, 'Bia': False}
# session_num 464. r2: 0.87,  RMSE: 0.2438
# --- Starting trial: run-465
# {'Lag': 283, 'Bia': True}
# session_num 465. r2: 0.87,  RMSE: 0.2439
# --- Starting trial: run-466
# {'Lag': 284, 'Bia': False}
# session_num 466. r2: 0.87,  RMSE: 0.2414
# --- Starting trial: run-467
# {'Lag': 284, 'Bia': True}
# session_num 467. r2: 0.87,  RMSE: 0.2414
# --- Starting trial: run-468
# {'Lag': 285, 'Bia': False}
# session_num 468. r2: 0.88,  RMSE: 0.2363
# --- Starting trial: run-469
# {'Lag': 285, 'Bia': True}
# session_num 469. r2: 0.88,  RMSE: 0.2363
# --- Starting trial: run-470
# {'Lag': 286, 'Bia': False}
# session_num 470. r2: 0.88,  RMSE: 0.2331
# --- Starting trial: run-471
# {'Lag': 286, 'Bia': True}
# session_num 471. r2: 0.88,  RMSE: 0.2331
# --- Starting trial: run-472
# {'Lag': 287, 'Bia': False}
# session_num 472. r2: 0.88,  RMSE: 0.2335
# --- Starting trial: run-473
# {'Lag': 287, 'Bia': True}
# session_num 473. r2: 0.88,  RMSE: 0.2335
# --- Starting trial: run-474
# {'Lag': 288, 'Bia': False}
# session_num 474. r2: 0.88,  RMSE: 0.2336
# --- Starting trial: run-475
# {'Lag': 288, 'Bia': True}
# session_num 475. r2: 0.88,  RMSE: 0.2336
# --- Starting trial: run-476
# {'Lag': 289, 'Bia': False}
# session_num 476. r2: 0.88,  RMSE: 0.2339
# --- Starting trial: run-477
# {'Lag': 289, 'Bia': True}
# session_num 477. r2: 0.88,  RMSE: 0.2339
# --- Starting trial: run-478
# {'Lag': 290, 'Bia': False}
# session_num 478. r2: 0.88,  RMSE: 0.2340
# --- Starting trial: run-479
# {'Lag': 290, 'Bia': True}
# session_num 479. r2: 0.88,  RMSE: 0.2341
# --- Starting trial: run-480
# {'Lag': 291, 'Bia': False}
# session_num 480. r2: 0.88,  RMSE: 0.2340
# --- Starting trial: run-481
# {'Lag': 291, 'Bia': True}
# session_num 481. r2: 0.88,  RMSE: 0.2340
# --- Starting trial: run-482
# {'Lag': 292, 'Bia': False}
# session_num 482. r2: 0.88,  RMSE: 0.2337
# --- Starting trial: run-483
# {'Lag': 292, 'Bia': True}
# session_num 483. r2: 0.88,  RMSE: 0.2337
# --- Starting trial: run-484
# {'Lag': 293, 'Bia': False}
# session_num 484. r2: 0.88,  RMSE: 0.2333
# --- Starting trial: run-485
# {'Lag': 293, 'Bia': True}
# session_num 485. r2: 0.88,  RMSE: 0.2333
# --- Starting trial: run-486
# {'Lag': 294, 'Bia': False}
# session_num 486. r2: 0.88,  RMSE: 0.2327
# --- Starting trial: run-487
# {'Lag': 294, 'Bia': True}
# session_num 487. r2: 0.88,  RMSE: 0.2327
# --- Starting trial: run-488
# {'Lag': 295, 'Bia': False}
# session_num 488. r2: 0.88,  RMSE: 0.2307
# --- Starting trial: run-489
# {'Lag': 295, 'Bia': True}
# session_num 489. r2: 0.88,  RMSE: 0.2307
# --- Starting trial: run-490
# {'Lag': 296, 'Bia': False}
# session_num 490. r2: 0.88,  RMSE: 0.2295
# --- Starting trial: run-491
# {'Lag': 296, 'Bia': True}
# session_num 491. r2: 0.88,  RMSE: 0.2295
# --- Starting trial: run-492
# {'Lag': 297, 'Bia': False}
# session_num 492. r2: 0.88,  RMSE: 0.2298
# --- Starting trial: run-493
# {'Lag': 297, 'Bia': True}
# session_num 493. r2: 0.88,  RMSE: 0.2298
# --- Starting trial: run-494
# {'Lag': 298, 'Bia': False}
# session_num 494. r2: 0.88,  RMSE: 0.2301
# --- Starting trial: run-495
# {'Lag': 298, 'Bia': True}
# session_num 495. r2: 0.88,  RMSE: 0.2301
# --- Starting trial: run-496
# {'Lag': 299, 'Bia': False}
# session_num 496. r2: 0.88,  RMSE: 0.2304
# --- Starting trial: run-497
# {'Lag': 299, 'Bia': True}
# session_num 497. r2: 0.88,  RMSE: 0.2304
# --- Starting trial: run-498
# {'Lag': 300, 'Bia': False}
# session_num 498. r2: 0.88,  RMSE: 0.2302
# --- Starting trial: run-499
# {'Lag': 300, 'Bia': True}
# session_num 499. r2: 0.88,  RMSE: 0.2301
# --- Starting trial: run-500
# {'Lag': 301, 'Bia': False}
# session_num 500. r2: 0.89,  RMSE: 0.2260
# --- Starting trial: run-501
# {'Lag': 301, 'Bia': True}
# session_num 501. r2: 0.89,  RMSE: 0.2260
# --- Starting trial: run-502
# {'Lag': 302, 'Bia': False}
# session_num 502. r2: 0.89,  RMSE: 0.2255
# --- Starting trial: run-503
# {'Lag': 302, 'Bia': True}
# session_num 503. r2: 0.89,  RMSE: 0.2255
# --- Starting trial: run-504
# {'Lag': 303, 'Bia': False}
# session_num 504. r2: 0.89,  RMSE: 0.2256
# --- Starting trial: run-505
# {'Lag': 303, 'Bia': True}
# session_num 505. r2: 0.89,  RMSE: 0.2256
# --- Starting trial: run-506
# {'Lag': 304, 'Bia': False}
# session_num 506. r2: 0.89,  RMSE: 0.2256
# --- Starting trial: run-507
# {'Lag': 304, 'Bia': True}
# session_num 507. r2: 0.89,  RMSE: 0.2256
# --- Starting trial: run-508
# {'Lag': 305, 'Bia': False}
# session_num 508. r2: 0.89,  RMSE: 0.2253
# --- Starting trial: run-509
# {'Lag': 305, 'Bia': True}
# session_num 509. r2: 0.89,  RMSE: 0.2253
# --- Starting trial: run-510
# {'Lag': 306, 'Bia': False}
# session_num 510. r2: 0.89,  RMSE: 0.2255
# --- Starting trial: run-511
# {'Lag': 306, 'Bia': True}
# session_num 511. r2: 0.89,  RMSE: 0.2255
# --- Starting trial: run-512
# {'Lag': 307, 'Bia': False}
# session_num 512. r2: 0.89,  RMSE: 0.2255
# --- Starting trial: run-513
# {'Lag': 307, 'Bia': True}
# session_num 513. r2: 0.89,  RMSE: 0.2255
# --- Starting trial: run-514
# {'Lag': 308, 'Bia': False}
# session_num 514. r2: 0.89,  RMSE: 0.2259
# --- Starting trial: run-515
# {'Lag': 308, 'Bia': True}
# session_num 515. r2: 0.89,  RMSE: 0.2258
# --- Starting trial: run-516
# {'Lag': 309, 'Bia': False}
# session_num 516. r2: 0.89,  RMSE: 0.2259
# --- Starting trial: run-517
# {'Lag': 309, 'Bia': True}
# session_num 517. r2: 0.89,  RMSE: 0.2259
# --- Starting trial: run-518
# {'Lag': 310, 'Bia': False}
# session_num 518. r2: 0.89,  RMSE: 0.2256
# --- Starting trial: run-519
# {'Lag': 310, 'Bia': True}
# session_num 519. r2: 0.89,  RMSE: 0.2256
# --- Starting trial: run-520
# {'Lag': 311, 'Bia': False}
# session_num 520. r2: 0.89,  RMSE: 0.2250
# --- Starting trial: run-521
# {'Lag': 311, 'Bia': True}
# session_num 521. r2: 0.89,  RMSE: 0.2250
# --- Starting trial: run-522
# {'Lag': 312, 'Bia': False}
# session_num 522. r2: 0.89,  RMSE: 0.2251
# --- Starting trial: run-523
# {'Lag': 312, 'Bia': True}
# session_num 523. r2: 0.89,  RMSE: 0.2251
# --- Starting trial: run-524
# {'Lag': 313, 'Bia': False}
# session_num 524. r2: 0.89,  RMSE: 0.2226
# --- Starting trial: run-525
# {'Lag': 313, 'Bia': True}
# session_num 525. r2: 0.89,  RMSE: 0.2226
# --- Starting trial: run-526
# {'Lag': 314, 'Bia': False}
# session_num 526. r2: 0.89,  RMSE: 0.2224
# --- Starting trial: run-527
# {'Lag': 314, 'Bia': True}
# session_num 527. r2: 0.89,  RMSE: 0.2223
# --- Starting trial: run-528
# {'Lag': 315, 'Bia': False}
# session_num 528. r2: 0.89,  RMSE: 0.2224
# --- Starting trial: run-529
# {'Lag': 315, 'Bia': True}
# session_num 529. r2: 0.89,  RMSE: 0.2224
# --- Starting trial: run-530
# {'Lag': 316, 'Bia': False}
# session_num 530. r2: 0.89,  RMSE: 0.2226
# --- Starting trial: run-531
# {'Lag': 316, 'Bia': True}
# session_num 531. r2: 0.89,  RMSE: 0.2226
# --- Starting trial: run-532
# {'Lag': 317, 'Bia': False}
# session_num 532. r2: 0.89,  RMSE: 0.2227
# --- Starting trial: run-533
# {'Lag': 317, 'Bia': True}
# session_num 533. r2: 0.89,  RMSE: 0.2227
# --- Starting trial: run-534
# {'Lag': 318, 'Bia': False}
# session_num 534. r2: 0.89,  RMSE: 0.2227
# --- Starting trial: run-535
# {'Lag': 318, 'Bia': True}
# session_num 535. r2: 0.89,  RMSE: 0.2227
# --- Starting trial: run-536
# {'Lag': 319, 'Bia': False}
# session_num 536. r2: 0.89,  RMSE: 0.2220
# --- Starting trial: run-537
# {'Lag': 319, 'Bia': True}
# session_num 537. r2: 0.89,  RMSE: 0.2220
# --- Starting trial: run-538
# {'Lag': 320, 'Bia': False}
# session_num 538. r2: 0.89,  RMSE: 0.2211
# --- Starting trial: run-539
# {'Lag': 320, 'Bia': True}
# session_num 539. r2: 0.89,  RMSE: 0.2211
# --- Starting trial: run-540
# {'Lag': 321, 'Bia': False}
# session_num 540. r2: 0.89,  RMSE: 0.2205
# --- Starting trial: run-541
# {'Lag': 321, 'Bia': True}
# session_num 541. r2: 0.89,  RMSE: 0.2205
# --- Starting trial: run-542
# {'Lag': 322, 'Bia': False}
# session_num 542. r2: 0.89,  RMSE: 0.2209
# --- Starting trial: run-543
# {'Lag': 322, 'Bia': True}
# session_num 543. r2: 0.89,  RMSE: 0.2209
# --- Starting trial: run-544
# {'Lag': 323, 'Bia': False}
# session_num 544. r2: 0.89,  RMSE: 0.2213
# --- Starting trial: run-545
# {'Lag': 323, 'Bia': True}
# session_num 545. r2: 0.89,  RMSE: 0.2213
# --- Starting trial: run-546
# {'Lag': 324, 'Bia': False}
# session_num 546. r2: 0.89,  RMSE: 0.2212
# --- Starting trial: run-547
# {'Lag': 324, 'Bia': True}
# session_num 547. r2: 0.89,  RMSE: 0.2213
# --- Starting trial: run-548
# {'Lag': 325, 'Bia': False}
# session_num 548. r2: 0.89,  RMSE: 0.2212
# --- Starting trial: run-549
# {'Lag': 325, 'Bia': True}
# session_num 549. r2: 0.89,  RMSE: 0.2212
# --- Starting trial: run-550
# {'Lag': 326, 'Bia': False}
# session_num 550. r2: 0.89,  RMSE: 0.2211
# --- Starting trial: run-551
# {'Lag': 326, 'Bia': True}
# session_num 551. r2: 0.89,  RMSE: 0.2211
# --- Starting trial: run-552
# {'Lag': 327, 'Bia': False}
# session_num 552. r2: 0.89,  RMSE: 0.2192
# --- Starting trial: run-553
# {'Lag': 327, 'Bia': True}
# session_num 553. r2: 0.89,  RMSE: 0.2192
# --- Starting trial: run-554
# {'Lag': 328, 'Bia': False}
# session_num 554. r2: 0.89,  RMSE: 0.2189
# --- Starting trial: run-555
# {'Lag': 328, 'Bia': True}
# session_num 555. r2: 0.89,  RMSE: 0.2189
# --- Starting trial: run-556
# {'Lag': 329, 'Bia': False}
# session_num 556. r2: 0.89,  RMSE: 0.2189
# --- Starting trial: run-557
# {'Lag': 329, 'Bia': True}
# session_num 557. r2: 0.89,  RMSE: 0.2189
# --- Starting trial: run-558
# {'Lag': 330, 'Bia': False}
# session_num 558. r2: 0.89,  RMSE: 0.2188
# --- Starting trial: run-559
# {'Lag': 330, 'Bia': True}
# session_num 559. r2: 0.89,  RMSE: 0.2189
# --- Starting trial: run-560
# {'Lag': 331, 'Bia': False}
# session_num 560. r2: 0.89,  RMSE: 0.2181
# --- Starting trial: run-561
# {'Lag': 331, 'Bia': True}
# session_num 561. r2: 0.89,  RMSE: 0.2181
# --- Starting trial: run-562
# {'Lag': 332, 'Bia': False}
# session_num 562. r2: 0.90,  RMSE: 0.2166
# --- Starting trial: run-563
# {'Lag': 332, 'Bia': True}
# session_num 563. r2: 0.90,  RMSE: 0.2166
# --- Starting trial: run-564
# {'Lag': 333, 'Bia': False}
# session_num 564. r2: 0.90,  RMSE: 0.2127
# --- Starting trial: run-565
# {'Lag': 333, 'Bia': True}
# session_num 565. r2: 0.90,  RMSE: 0.2127
# --- Starting trial: run-566
# {'Lag': 334, 'Bia': False}
# session_num 566. r2: 0.90,  RMSE: 0.2092
# --- Starting trial: run-567
# {'Lag': 334, 'Bia': True}
# session_num 567. r2: 0.90,  RMSE: 0.2092
# --- Starting trial: run-568
# {'Lag': 335, 'Bia': False}
# session_num 568. r2: 0.90,  RMSE: 0.2078
# --- Starting trial: run-569
# {'Lag': 335, 'Bia': True}
# session_num 569. r2: 0.90,  RMSE: 0.2078
# --- Starting trial: run-570
# {'Lag': 336, 'Bia': False}
# session_num 570. r2: 0.90,  RMSE: 0.2080
# --- Starting trial: run-571
# {'Lag': 336, 'Bia': True}
# session_num 571. r2: 0.90,  RMSE: 0.2080
# --- Starting trial: run-572
# {'Lag': 337, 'Bia': False}
# session_num 572. r2: 0.91,  RMSE: 0.1958
# --- Starting trial: run-573
# {'Lag': 337, 'Bia': True}
# session_num 573. r2: 0.91,  RMSE: 0.1958
# --- Starting trial: run-574
# {'Lag': 338, 'Bia': False}
# session_num 574. r2: 0.91,  RMSE: 0.1952
# --- Starting trial: run-575
# {'Lag': 338, 'Bia': True}
# session_num 575. r2: 0.91,  RMSE: 0.1951
# --- Starting trial: run-576
# {'Lag': 339, 'Bia': False}
# session_num 576. r2: 0.91,  RMSE: 0.1953
# --- Starting trial: run-577
# {'Lag': 339, 'Bia': True}
# session_num 577. r2: 0.91,  RMSE: 0.1953
# --- Starting trial: run-578
# {'Lag': 340, 'Bia': False}
# session_num 578. r2: 0.91,  RMSE: 0.1949
# --- Starting trial: run-579
# {'Lag': 340, 'Bia': True}
# session_num 579. r2: 0.91,  RMSE: 0.1948
# --- Starting trial: run-580
# {'Lag': 341, 'Bia': False}
# session_num 580. r2: 0.91,  RMSE: 0.1943
# --- Starting trial: run-581
# {'Lag': 341, 'Bia': True}
# session_num 581. r2: 0.91,  RMSE: 0.1942
# --- Starting trial: run-582
# {'Lag': 342, 'Bia': False}
# session_num 582. r2: 0.91,  RMSE: 0.1935
# --- Starting trial: run-583
# {'Lag': 342, 'Bia': True}
# session_num 583. r2: 0.91,  RMSE: 0.1934
# --- Starting trial: run-584
# {'Lag': 343, 'Bia': False}
# session_num 584. r2: 0.92,  RMSE: 0.1914
# --- Starting trial: run-585
# {'Lag': 343, 'Bia': True}
# session_num 585. r2: 0.92,  RMSE: 0.1913
# --- Starting trial: run-586
# {'Lag': 344, 'Bia': False}
# session_num 586. r2: 0.92,  RMSE: 0.1900
# --- Starting trial: run-587
# {'Lag': 344, 'Bia': True}
# session_num 587. r2: 0.92,  RMSE: 0.1900
# --- Starting trial: run-588
# {'Lag': 345, 'Bia': False}
# session_num 588. r2: 0.92,  RMSE: 0.1902
# --- Starting trial: run-589
# {'Lag': 345, 'Bia': True}
# session_num 589. r2: 0.92,  RMSE: 0.1901
# --- Starting trial: run-590
# {'Lag': 346, 'Bia': False}
# session_num 590. r2: 0.92,  RMSE: 0.1902
# --- Starting trial: run-591
# {'Lag': 346, 'Bia': True}
# session_num 591. r2: 0.92,  RMSE: 0.1901
# --- Starting trial: run-592
# {'Lag': 347, 'Bia': False}
# session_num 592. r2: 0.92,  RMSE: 0.1903
# --- Starting trial: run-593
# {'Lag': 347, 'Bia': True}
# session_num 593. r2: 0.92,  RMSE: 0.1903
# --- Starting trial: run-594
# {'Lag': 348, 'Bia': False}
# session_num 594. r2: 0.92,  RMSE: 0.1903
# --- Starting trial: run-595
# {'Lag': 348, 'Bia': True}
# session_num 595. r2: 0.92,  RMSE: 0.1902
# --- Starting trial: run-596
# {'Lag': 349, 'Bia': False}
# session_num 596. r2: 0.92,  RMSE: 0.1906
# --- Starting trial: run-597
# {'Lag': 349, 'Bia': True}
# session_num 597. r2: 0.92,  RMSE: 0.1906
# --- Starting trial: run-598
# {'Lag': 350, 'Bia': False}
# session_num 598. r2: 0.92,  RMSE: 0.1907
# --- Starting trial: run-599
# {'Lag': 350, 'Bia': True}
# session_num 599. r2: 0.92,  RMSE: 0.1907
# ALL COMBINATIONS ARE NOW TRAINED!

# %%
print(f"tensorboard --logdir={CurLogsDir}") #Run from the anaconda terminal
# Out:
# tensorboard --logdir=C:/logs/2021-06-21_01-17-58/

# %% [markdown]
# http://localhost:6006
